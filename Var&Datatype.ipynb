# %% [markdown]
# Variable & Datatype

# %%
s = 65
t = 55
e = s<=t
print(e)
# Out:
# False

# %%
d = 45 
v = 22
i = d>=v
print(i)
# Out:
# True

# %%
V = 45 #int
D = 22.45 #float
T = "maths" #str.

# %%
print("Hello Sir")
print(V)
print(D)
print(T)
# Out:
# Hello Sir
# 45
# 22.45
# maths

# %%
D = 94
S = 96.23
W = "professor" 
print(W)
# Out:
# professor

# %%
print(id(D))
print(type(D))
print(id(S))
print(type(V))
print(id(W))
print(type(W))
# Out:
# 140722292633416
# <class 'int'>
# 1867951598160
# <class 'int'>
# 1867953340656
# <class 'str'>

# %%
Name = str(input("Enter your name"))
Address = str(input("Enter your address"))
Number = int(input("Enter your number"))
Eduction = str(input("Eduction"))
Percentage = float(input("Enter your percentage"))
# Out:
# Enter your name Dev Thakkar
# Enter your address vithal nivas krishna park jamnagar
# Enter your number 9173777855
# Eduction B.com sem-4
# Enter your percentage 65.65

# %%
credit = int(input("enter  your credit"))
Balanace = int(input("balance"))
print("your credit", credit, "your Remaining balance", Balanace, "date28/03/2026" )
# Out:
# enter  your credit 50000
# balance 100000
# your credit 50000 your Remaining balance 100000 date28/03/2026

# %%
print("Date28/03/2026")
credit = int(input("enter  your credit"))
Balanace = ("100000")
print("Balanace","100000")
print("your credit", credit, "IN Bank Of Baroda Account" , "your Remaining balance", Balanace, "date28/03/2026" )
# Out:
# Date28/03/2026
# enter  your credit 50000
# Balanace 100000
# your credit 50000 IN Bank Of Baroda Account your Remaining balance 100000 date28/03/2026

# %%
print("successful Var$datatype")
print("Thankyou")
# Out:
# successful Var$datatype
# Thankyou
