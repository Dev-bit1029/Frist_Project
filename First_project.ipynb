# %% [markdown]
# First_project

# %%
a = 229489
b = 4522
c = a+b
print(c)
# Out:
# 234011

# %%
a = 91 
v = 93
d = a-v
print(d)
# Out:
# -2

# %%
s = 96
d = 94
a = s*d
print(a)
# Out:
# 9024

# %%
a = 789
A = 987
T = a/A
print(T)
# Out:
# 0.7993920972644377

# %%
d = 45 
v = 22
i = d>=v
print(i)
# Out:
# True

# %%
s = 65
t = 55
e = s<=T
print(e)
# Out:
# False

# %%
a,b,c,d = 1,2,3.5,4.5
print(a)
print(b)
print("Hello Dev Thakkar")
print(c)
print(d)
# Out:
# 1
# 2
# Hello Dev Thakkar
# 3.5
# 4.5

# %%
a,b,c,d = 1.2,1.5,2.5,3.5
f = a+b
g = c*d 
h = a-b
j = c/d

# %%
print(f)
print(g)
print(h)
print(j)
# Out:
# 2.7
# 8.75
# -0.30000000000000004
# 0.7142857142857143

# %%
print("successful First_project")
print("Thankyou")
# Out:
# successful First_project
# Thankyou
