# %% [markdown]
# :- Operator In Python

# %% [markdown]
# 1. Arithmetic operator

# %%
A = 456
B = 654
print(id(A))
print(id(B))
print("Hello Professor")
# Out:
# 1385818377520
# 1385818377712
# Hello Professor

# %%
D = 4452
V = 2254
Addition = D+V
print(Addition)
# Out:
# 6706

# %%
Q = 963
W = 369
Addition = Q+W
print(Addition)
print(id(W))
print(id(Q))
# Out:
# 1332
# 1385818377232
# 1385818377840

# %%
S = 789
D = 987
Subraction = S-D
print(Subraction)
# Out:
# -198

# %%
V = 456
P = 123
K = V>=P
print(K)
subraction = V-P
print(subraction)
# Out:
# True
# 333

# %%
Devision = V/P
print(Devision)
# Out:
# 3.707317073170732

# %%
Y = 12.25
U = 23.23
I = Y>=U
Devision = Y/U
print(I)
print(Devision)
# Out:
# False
# 0.5273353422298751

# %%
M = Y*U
print(M)
# Out:
# 284.5675

# %%
F = 23
G = 10
Exponential = F**G
print(Exponential)
# Out:
# 41426511213649

# %%
E = 3
I = 12
e = E**I
print(e)
# Out:
# 531441

# %% [markdown]
# Comparison Operator

# %%
A = 229
a = 452
print(A<a)
# Out:
# True

# %%
S = 100.25
D = 220.25
print(S<D)
# Out:
# True

# %%
N = 963
M = 3699
print(N>M)
# Out:
# False

# %%
T = 456
P = 654
print(T<P)
print(T>=P)
print(T==P)
print(T<=P)
# Out:
# True
# False
# False
# True

# %%
V = 452
D = 452
print(V==D)
# Out:
# True

# %% [markdown]
# Assignment Operator

# %%
A = 789
B = 987
C = 0
C = A+B 
print("Value of C is",C)
print(C)
# Out:
# Value of C is 1776
# 1776

# %%
V = 159
K = 951
P = 0
P = V/K
print("value of P is", P)
# Out:
# value of P is 0.167192429022082

# %%
D = 452
V = 229
T = D=+V
print("value of componding is",T)
# Out:
# value of componding is 229

# %%
t = D=-V
print(t)
# Out:
# -229

# %%
D = 6
V = 2
D**V
# Out:
# 36

# %%
C = 8
X = 10
B = C//X
print(B)
# Out:
# 0

# %%
N = C**X
print(N)
# Out:
# 1073741824

# %%
W = 10
Q = 65
E = W%Q
print(E)
# Out:
# 10

# %%
W**=Q
print(Q)
# Out:
# 65

# %%
W //= Q 
print(W)
# Out:
# 0

# %%
W%=Q
print(W)
print(Q)
# Out:
# 0
# 65

# %%
print(12.21**3.33)
print(12.12//21.21)
print(56%12)
# Out:
# 4156.838587637206
# 0.0
# 8

# %% [markdown]
# Bit Operator is doubt

# %%
print("Complately Operator")
# Out:
# Complately Operator
